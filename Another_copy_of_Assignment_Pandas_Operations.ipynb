# %% [markdown]
# <a href="https://colab.research.google.com/github/anandkumar393/python_library/blob/main/Another_copy_of_Assignment_Pandas_Operations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# DATA SET: https://drive.google.com/file/d/1Ps0FgcAsca9oxq5W4FEBdBiPx-YYe-33/view?usp=sharing

# %% [markdown]
# ## <u> Use only those concepts which have been taught till now </u>

# %% [markdown]
# # <b> Problem 1: Import Pandas and Numpy in the notebook </b>

# %%
# Import statements
import numpy as np
import pandas as pd

# %% [markdown]
# # <b> Problem 2 : Load the automobile_data.csv kept in the shared folder

# %%
# Mount your drive and read the csv file. Make sure you are using the correct file path

df=pd.read_csv('/content/automobile_data.csv')

# %% [markdown]
# # <b> Problem 3 : Do a basic inspection and print the first and last 15 rows of your dataframe

# %%
# Your code here
df.head(15)
# Out:
#     symboling normalized-losses         make fuel-type aspiration  \
# 0           3                 ?  alfa-romero       gas        std
# 1           3                 ?  alfa-romero       gas        std
# 2           1                 ?  alfa-romero       gas        std
# 3           2               164         audi       gas        std
# 4           2               164         audi       gas        std
# 5           2                 ?         audi       gas        std
# 6           1               158         audi       gas        std
# 7           1                 ?         audi       gas        std
# 8           1               158         audi       gas      turbo
# 9           0                 ?         audi       gas      turbo
# 10          2               192          bmw       gas        std
# 11          0               192          bmw       gas        std
# 12          0               188          bmw       gas        std
# 13          0               188          bmw       gas        std
# 14          1                 ?          bmw       gas        std
#
#    num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0           two  convertible          rwd           front        88.6  ...
# 1           two  convertible          rwd           front        88.6  ...
# 2           two    hatchback          rwd           front        94.5  ...
# 3          four        sedan          fwd           front        99.8  ...
# 4          four        sedan          4wd           front        99.4  ...
# 5           two        sedan          fwd           front        99.8  ...
# 6          four        sedan          fwd           front       105.8  ...
# 7          four        wagon          fwd           front       105.8  ...
# 8          four        sedan          fwd           front       105.8  ...
# 9           two    hatchback          4wd           front        99.5  ...
# 10          two        sedan          rwd           front       101.2  ...
# 11         four        sedan          rwd           front       101.2  ...
# 12          two        sedan          rwd           front       101.2  ...
# 13         four        sedan          rwd           front       101.2  ...
# 14         four        sedan          rwd           front       103.5  ...
#
#     engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0           130         mpfi  3.47    2.68               9.0        111
# 1           130         mpfi  3.47    2.68               9.0        111
# 2           152         mpfi  2.68    3.47               9.0        154
# 3           109         mpfi  3.19     3.4              10.0        102
# 4           136         mpfi  3.19     3.4               8.0        115
# 5           136         mpfi  3.19     3.4               8.5        110
# 6           136         mpfi  3.19     3.4               8.5        110
# 7           136         mpfi  3.19     3.4               8.5        110
# 8           131         mpfi  3.13     3.4               8.3        140
# 9           131         mpfi  3.13     3.4               7.0        160
# 10          108         mpfi   3.5     2.8               8.8        101
# 11          108         mpfi   3.5     2.8               8.8        101
# 12          164         mpfi  3.31    3.19               9.0        121
# 13          164         mpfi  3.31    3.19               9.0        121
# 14          164         mpfi  3.31    3.19               9.0        121
#
#     peak-rpm city-mpg highway-mpg  price
# 0       5000       21          27  13495
# 1       5000       21          27  16500
# 2       5000       19          26  16500
# 3       5500       24          30  13950
# 4       5500       18          22  17450
# 5       5500       19          25  15250
# 6       5500       19          25  17710
# 7       5500       19          25  18920
# 8       5500       17          20  23875
# 9       5500       16          22      ?
# 10      5800       23          29  16430
# 11      5800       23          29  16925
# 12      4250       21          28  20970
# 13      4250       21          28  21105
# 14      4250       20          25  24565
#
# [15 rows x 26 columns]

# %% [markdown]
# # <b>Problem 4 : You need to clean the data a little bit now. Replace all column values with the values <code>?</code> and <code>n.a</code> with <code>NaN</code>

# %%
# Your code here
df=df.replace('?',np.nan)

# %%
df=df.replace('n.a',np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               201 non-null    object
#  19  stroke             201 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         203 non-null    object
#  22  peak-rpm           203 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
df.isnull().sum()
# Out:
# symboling             0
# normalized-losses    41
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  164 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       203 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
#  16  engine-size        205 non-null    int64
#  17  fuel-system        205 non-null    object
#  18  bore               201 non-null    object
#  19  stroke             201 non-null    object
#  20  compression-ratio  205 non-null    float64
#  21  horsepower         203 non-null    object
#  22  peak-rpm           203 non-null    object
#  23  city-mpg           205 non-null    int64
#  24  highway-mpg        205 non-null    int64
#  25  price              201 non-null    object
# dtypes: float64(5), int64(5), object(16)
# memory usage: 41.8+ KB

# %%
df['normalized-losses']=df['normalized-losses'].astype(float)

# %%
df['normalized-losses'].min()
# Out:
# 65.0

# %%
df['normalized-losses'].max()
# Out:
# 256.0

# %%
df['normalized-losses'].mean()
# Out:
# 122.0

# %%
df['normalized-losses'].median()
# Out:
# 115.0

# %%
df['normalized-losses'].fillna(df['normalized-losses'].mean(),inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0          two  convertible          rwd           front        88.6  ...
# 1          two  convertible          rwd           front        88.6  ...
# 2          two    hatchback          rwd           front        94.5  ...
# 3         four        sedan          fwd           front        99.8  ...
# 4         four        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19     3.4              10.0        102
# 4          136         mpfi  3.19     3.4               8.0        115
#
#    peak-rpm city-mpg highway-mpg  price
# 0      5000       21          27  13495
# 1      5000       21          27  16500
# 2      5000       19          26  16500
# 3      5500       24          30  13950
# 4      5500       18          22  17450
#
# [5 rows x 26 columns]

# %%
df['num-of-doors']=df['num-of-doors'].mode()

# %%
df['num-of-doors'].fillna(df['num-of-doors'].mode(),inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0         four  convertible          rwd           front        88.6  ...
# 1          NaN  convertible          rwd           front        88.6  ...
# 2          NaN    hatchback          rwd           front        94.5  ...
# 3          NaN        sedan          fwd           front        99.8  ...
# 4          NaN        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19     3.4              10.0        102
# 4          136         mpfi  3.19     3.4               8.0        115
#
#    peak-rpm city-mpg highway-mpg  price
# 0      5000       21          27  13495
# 1      5000       21          27  16500
# 2      5000       19          26  16500
# 3      5500       24          30  13950
# 4      5500       18          22  17450
#
# [5 rows x 26 columns]

# %%
df['bore']=df['bore'].astype(float)

# %%
df['bore'].mean().round(0)
# Out:
# 3.0

# %%
df['bore'].fillna(df['bore'].mean(),inplace=True)

# %%
df['stroke']=df['stroke'].astype(float)

# %%
df['stroke'].mean().round(0)
# Out:
# 3.0

# %%
df['stroke'].fillna(df['stroke'].mean(),inplace=True)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0         four  convertible          rwd           front        88.6  ...
# 1          NaN  convertible          rwd           front        88.6  ...
# 2          NaN    hatchback          rwd           front        94.5  ...
# 3          NaN        sedan          fwd           front        99.8  ...
# 4          NaN        sedan          4wd           front        99.4  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
# 2          152         mpfi  2.68    3.47               9.0        154
# 3          109         mpfi  3.19    3.40              10.0        102
# 4          136         mpfi  3.19    3.40               8.0        115
#
#    peak-rpm city-mpg  highway-mpg  price
# 0      5000       21           27  13495
# 1      5000       21           27  16500
# 2      5000       19           26  16500
# 3      5500       24           30  13950
# 4      5500       18           22  17450
#
# [5 rows x 26 columns]

# %% [markdown]
# # <b>Problem 5 : Print the company name which manufactured the most expensive car. Also print the price of the most expensive car

# %%
# Your code here
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df['price'].isnull().sum()
# Out:
# 4

# %%
df['price']=df['price'].astype(float)

# %%
df['price'].fillna(df['price'].mean(),inplace=True)

# %%
df['price'].max()
# Out:
# 45400.0

# %%
df.query(" price==45400.0 ")[['make','price']]
# Out:
#              make    price
# 74  mercedes-benz  45400.0

# %% [markdown]
# # <b>Problem 6 : Calculate maximum horsepowers for each company. </b>

# %%
df.head(2)
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0         four  convertible          rwd           front        88.6  ...
# 1          NaN  convertible          rwd           front        88.6  ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# 0          130         mpfi  3.47    2.68               9.0        111
# 1          130         mpfi  3.47    2.68               9.0        111
#
#    peak-rpm city-mpg  highway-mpg    price
# 0      5000       21           27  13495.0
# 1      5000       21           27  16500.0
#
# [2 rows x 26 columns]

# %%
df.groupby('make')['horsepower'].max()
# Out:
# make
# alfa-romero      154
# audi             160
# bmw              182
# chevrolet         70
# dodge             88
# honda             86
# isuzu             90
# jaguar           262
# mazda             84
# mercedes-benz    184
# mercury          175
# mitsubishi        88
# nissan            97
# peugot            97
# plymouth          88
# porsche          288
# renault          NaN
# saab             160
# subaru            94
# toyota            92
# volkswagen        90
# volvo            162
# Name: horsepower, dtype: object

# %%
# Your code here

# %%
# Your code here

# %% [markdown]
# # <b> Problem 8 : Create a new column for the updated price. This updated price will be calculated on top of the given price - if the engine is in front, price will be same else if the engine is in rear, price will be doubled </b>

# %%
df.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-mpg', 'price'],
#       dtype='object')

# %%
df['engine-location'].unique()
# Out:
# array(['front', 'rear'], dtype=object)

# %%
for i in df['engine-location']:
  print(i)
  break
# Out:
# front

# %%
# Your code here. Use apply and lambda
def new_price(df):
  if df['engine-location']=='front':
      return df['price']
  elif df['engine-location']=='rear':
      return df['price']*2

df['updated_price']=df.apply(new_price,axis=1)

# %%
df.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3              122.0  alfa-romero       gas        std
# 1          3              122.0  alfa-romero       gas        std
# 2          1              122.0  alfa-romero       gas        std
# 3          2              164.0         audi       gas        std
# 4          2              164.0         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  ...  \
# 0         four  convertible          rwd           front        88.6  ...
# 1          NaN  convertible          rwd           front        88.6  ...
# 2          NaN    hatchback          rwd           front        94.5  ...
# 3          NaN        sedan          fwd           front        99.8  ...
# 4          NaN        sedan          4wd           front        99.4  ...
#
#    fuel-system  bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 0         mpfi  3.47    2.68                9.0        111     5000        21
# 1         mpfi  3.47    2.68                9.0        111     5000        21
# 2         mpfi  2.68    3.47                9.0        154     5000        19
# 3         mpfi  3.19    3.40               10.0        102     5500        24
# 4         mpfi  3.19    3.40                8.0        115     5500        18
#
#   highway-mpg    price  updated_price
# 0          27  13495.0        13495.0
# 1          27  16500.0        16500.0
# 2          26  16500.0        16500.0
# 3          30  13950.0        13950.0
# 4          22  17450.0        17450.0
#
# [5 rows x 27 columns]

# %%
df.query(" price<updated_price ")
# Out:
#      symboling  normalized-losses     make fuel-type aspiration num-of-doors  \
# 126          3              122.0  porsche       gas        std          NaN
# 127          3              122.0  porsche       gas        std          NaN
# 128          3              122.0  porsche       gas        std          NaN
#
#       body-style drive-wheels engine-location  wheel-base  ...  fuel-system  \
# 126      hardtop          rwd            rear        89.5  ...         mpfi
# 127      hardtop          rwd            rear        89.5  ...         mpfi
# 128  convertible          rwd            rear        89.5  ...         mpfi
#
#      bore  stroke  compression-ratio horsepower peak-rpm  city-mpg  \
# 126  3.74     2.9                9.5        207     5900        17
# 127  3.74     2.9                9.5        207     5900        17
# 128  3.74     2.9                9.5        207     5900        17
#
#     highway-mpg    price  updated_price
# 126          25  32528.0        65056.0
# 127          25  34028.0        68056.0
# 128          25  37028.0        74056.0
#
# [3 rows x 27 columns]

# %% [markdown]
# # <b>Problem 9 : Sort the dataframe by car and price columns

# %%
# Your code here
df[['make','price']].sort_values(by='price')
# Out:
#               make    price
# 138         subaru   5118.0
# 18       chevrolet   5151.0
# 50           mazda   5195.0
# 150         toyota   5348.0
# 76      mitsubishi   5389.0
# ..             ...      ...
# 17             bmw  36880.0
# 128        porsche  37028.0
# 73   mercedes-benz  40960.0
# 16             bmw  41315.0
# 74   mercedes-benz  45400.0
#
# [205 rows x 2 columns]

# %% [markdown]
# # <b> Problem 10 : Create a new column which stores the number of doors in a car as integers.

# %%
df['num-of-doors'].unique()
df=df.replace('?',np.nan)

# %%
df['num-of-doors'].unique()
# Out:
# array(['two', 'four', nan], dtype=object)

# %%
df['num-of-doors'].mode()
# Out:
# 0    four
# Name: num-of-doors, dtype: object

# %%
df['num-of-doors'].fillna(df['num-of-doors'].mode()[0],inplace=True)

# %%
# Your code here. Use apply
def new_doors(df):
  if df['num-of-doors']=='two':
    return 2
  elif df['num-of-doors']=='four':
    return 4
df['update_no_of_doors']=df.apply(new_doors,axis=1)

# %%
df['update_no_of_doors'].unique()
# Out:
# array([2, 4])

# %% [markdown]
# # <b>Problem 11 : Concatenate the two data frames given below firstly row wise and secondly column wise.</b>
#
# <code>GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}</code>
#
# <code>japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}</code>

# %%
# Your code here

GermanCars = {'Company': ['Ford', 'Mercedes', 'BMV', 'Audi'], 'Price': [23845, 171995, 135925 , 71400]}

japaneseCars = {'Company': ['Toyota', 'Honda', 'Nissan', 'Mitsubishi '], 'Price': [29995, 23600, 61500 , 58900]}

# %%
# concatenate


series1 = pd.Series([1, 2, 3])
display('series1:', series1)
series2 = pd.Series(['A', 'B', 'C'])
display('series2:', series2)
# Out:
# 'series1:'
# 0    1
# 1    2
# 2    3
# dtype: int64
# 'series2:'
# 0    A
# 1    B
# 2    C
# dtype: object

# %%
# concatenating
display('After concatenating:')
display(pd.concat([series1, series2]))
# Out:
# 'After concatenating:'
# 0    1
# 1    2
# 2    3
# 0    A
# 1    B
# 2    C
# dtype: object

# %%
df1 = pd.DataFrame({'A': ['A0', 'A1', 'A2', 'A3'],
                    'B': ['B0', 'B1', 'B2', 'B3'],
                    'C': ['B0', 'B1', 'B2', 'B3']})
display('df1:', df1)
df2 = pd.DataFrame({'A1': ['A4', 'A5', 'A6', 'A7'],
                    'B1': ['B4', 'B5', 'B6', 'B7'],
                    'C': ['B0', 'B1', 'B2', 'B3']})
display('df2:', df2)
# Out:
# 'df1:'
#     A   B   C
# 0  A0  B0  B0
# 1  A1  B1  B1
# 2  A2  B2  B2
# 3  A3  B3  B3
# 'df2:'
#    A1  B1   C
# 0  A4  B4  B0
# 1  A5  B5  B1
# 2  A6  B6  B2
# 3  A7  B7  B3

# %%
display(pd.concat([df1, df2],axis=1))
# Out:
#     A   B   C  A1  B1   C
# 0  A0  B0  B0  A4  B4  B0
# 1  A1  B1  B1  A5  B5  B1
# 2  A2  B2  B2  A6  B6  B2
# 3  A3  B3  B3  A7  B7  B3

# %%
# merge
# Define a dictionary containing employee data
data1 = {'key': ['K0', 'K1', 'K2', 'K3'],
         'Name':['Jai', 'Princi', 'Gaurav', 'Anuj'],
        'Age':[27, 24, 22, 32]}

# Define a dictionary containing employee data
data2 = {'key1': ['K0', 'K1', 'K2', 'K3'],
         'Address':['Nagpur', 'Kanpur', 'Allahabad', 'Kannuaj'],
        'Qualification':['Btech', 'B.A', 'Bcom', 'B.hons']}

# Convert the dictionary into DataFrame
df = pd.DataFrame(data1)

# Convert the dictionary into DataFrame
df1 = pd.DataFrame(data2)

# %%
df
# Out:
#   key key1    Name  Age
# 0  K0   K0     Jai   27
# 1  K1   K1  Princi   24
# 2  K2   K0  Gaurav   22
# 3  K3   K1    Anuj   32

# %%
df1
# Out:
#   key key1    Address Qualification
# 0  K0   K0     Nagpur         Btech
# 1  K1   K0     Kanpur           B.A
# 2  K2   K0  Allahabad          Bcom
# 3  K3   K0    Kannuaj        B.hons

# %%
res1 = pd.merge(df, df1)

# %%
res1
# Out:
#   key key1    Name  Age    Address Qualification
# 0  K0   K0     Jai   27     Nagpur         Btech
# 1  K2   K0  Gaurav   22  Allahabad          Bcom

# %%
df1 = pd.DataFrame({'lkey': ['foo', 'bar', 'baz', 'foo'],
                     'value': [1, 2, 3, 5]})
df2 = pd.DataFrame({'rkey': ['foo', 'bar', 'baz', 'foo'],
                     'value': [5, 6, 7, 8]})

# %%
df1
# Out:
#   lkey  value
# 0  foo      1
# 1  bar      2
# 2  baz      3
# 3  foo      5

# %%
df2
# Out:
#   rkey  value
# 0  foo      5
# 1  bar      6
# 2  baz      7
# 3  foo      8

# %%
df1.merge(df2, left_on='lkey', right_on='rkey')
# Out:
#   lkey  value_x rkey  value_y
# 0  foo        1  foo        5
# 1  foo        1  foo        8
# 2  foo        5  foo        5
# 3  foo        5  foo        8
# 4  bar        2  bar        6
# 5  baz        3  baz        7
